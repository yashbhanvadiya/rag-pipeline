# %%
from langchain_core.documents import Document
import os

# %%
doc = Document(
    page_content = "This is the main text content I am using to create RAG",
    metadata = {
        "source": "example.txt",
        "pages": 1,
        "author": "Yash Bhanvadiya",
        "data_created": "2026-04-16"
    }
)

# %%
## Create a simple txt file
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

    Python is a high-level, interpreted programming language known for its simplicity and readability.
    Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
    programming languages in the world.

    Key Features:
    - Easy to learn and use
    - Extensive standard library
    - Cross-platform compatibility
    - Strong community support

    Python is widely used in web development, data science, artificial intelligence, and automation.""",
        
        "../data/text_files/machine_learning.txt": """Machine Learning Basics

    Machine learning is a subset of artificial intelligence that enables systems to learn and improve
    from experience without being explicitly programmed. It focuses on developing computer programs
    that can access data and use it to learn for themselves.

    Types of Machine Learning:
    1. Supervised Learning: Learning with labeled data
    2. Unsupervised Learning: Finding patterns in unlabeled data
    3. Reinforcement Learning: Learning through rewards and penalties

    Applications include image recognition, speech processing, and recommendation systems
        
    """
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("Sample text files created!")
# Out:
# Sample text files created!

# %%
## Text Loader
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt", encoding="utf-8")
documents = loader.load()
documents
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\n    Python is a high-level, interpreted programming language known for its simplicity and readability.\n    Created by Guido van Rossum and first released in 1991, Python has become one of the most popular\n    programming languages in the world.\n\n    Key Features:\n    - Easy to learn and use\n    - Extensive standard library\n    - Cross-platform compatibility\n    - Strong community support\n\n    Python is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
## Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## Load all the text file from the directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob = "**/*.txt", ## pattern to match files
    loader_cls = TextLoader, ## loader class to use
    loader_kwargs = {"encoding": "utf-8"},
    show_progress = False
)

documents = dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\n    Machine learning is a subset of artificial intelligence that enables systems to learn and improve\n    from experience without being explicitly programmed. It focuses on developing computer programs\n    that can access data and use it to learn for themselves.\n\n    Types of Machine Learning:\n    1. Supervised Learning: Learning with labeled data\n    2. Unsupervised Learning: Finding patterns in unlabeled data\n    3. Reinforcement Learning: Learning through rewards and penalties\n\n    Applications include image recognition, speech processing, and recommendation systems\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\n    Python is a high-level, interpreted programming language known for its simplicity and readability.\n    Created by Guido van Rossum and first released in 1991, Python has become one of the most popular\n    programming languages in the world.\n\n    Key Features:\n    - Easy to learn and use\n    - Extensive standard library\n    - Cross-platform compatibility\n    - Strong community support\n\n    Python is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## Load all the text file from the directory
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob = "**/*.pdf", ## pattern to match files
    loader_cls = PyMuPDFLoader, ## loader class to use
    show_progress = False
)

pdf_documents = dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-16T12:26:11+00:00', 'source': '..\\data\\pdf\\ai_ml_technical_guide.pdf', 'file_path': '..\\data\\pdf\\ai_ml_technical_guide.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-04-16T12:26:11+00:00', 'trapped': '', 'modDate': "D:20260416122611+00'00'", 'creationDate': "D:20260416122611+00'00'", 'page': 0}, page_content='Artificial Intelligence & Machine\nLearning\nA Comprehensive Technical Reference Guide\n1. Introduction to Machine Learning\nMachine Learning (ML) is a subset of Artificial Intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. ML focuses on developing computer programs\nthat can access data and use it to learn for themselves. The process begins with observations or data,\nsuch as examples, direct experience, or instruction, to look for patterns in data and make better\ndecisions in the future.\n1.1 Types of Machine Learning\nType\nDescription\nExample Algorithms\nSupervised\nLearning\nLearns from labeled training data to predict outcomes\nLinear Regression, SVM, Neural Networks\nUnsupervised\nLearning\nFinds hidden patterns in unlabeled data\nK-Means, DBSCAN, Autoencoders\nReinforcement\nLearning\nLearns through reward/penalty interactions\nQ-Learning, PPO, A3C\nSemi-supervised\nCombines labeled and unlabeled data\nSelf-training, Label Propagation\nFigure 1: AI Model Performance Trend\n2020\n2021\n2022\n2023\n2024\n0\n20\n40\n60\n80\n100\nAI Model Accuracy (%) by Year\nSource: AI Benchmark Report 2024 — accuracy measured on standard test datasets.\n2. Deep Learning Fundamentals'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-16T12:26:11+00:00', 'source': '..\\data\\pdf\\ai_ml_technical_guide.pdf', 'file_path': '..\\data\\pdf\\ai_ml_technical_guide.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-04-16T12:26:11+00:00', 'trapped': '', 'modDate': "D:20260416122611+00'00'", 'creationDate': "D:20260416122611+00'00'", 'page': 1}, page_content='Deep Learning is a subset of machine learning based on artificial neural networks with multiple layers.\nThese networks are capable of learning representations from large amounts of data. Key architectures\ninclude Convolutional Neural Networks (CNNs) for image tasks, Recurrent Neural Networks (RNNs) for\nsequential data, and Transformer models for natural language processing.\nKey Deep Learning Parameters\nParameter\nTypical Range\nImpact\nLearning Rate\n0.0001 – 0.01\nControls convergence speed\nBatch Size\n16 – 512\nAffects memory and generalization\nEpochs\n10 – 1000\nTotal training iterations\nDropout Rate\n0.1 – 0.5\nRegularization, prevents overfitting\nHidden Layers\n2 – 100+\nModel capacity and complexity\nActivation Fn\nReLU, GELU, Sigmoid\nNon-linearity introduction'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-16T12:26:11+00:00', 'source': '..\\data\\pdf\\ai_ml_technical_guide.pdf', 'file_path': '..\\data\\pdf\\ai_ml_technical_guide.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-04-16T12:26:11+00:00', 'trapped': '', 'modDate': "D:20260416122611+00'00'", 'creationDate': "D:20260416122611+00'00'", 'page': 2}, page_content='3. Retrieval-Augmented Generation (RAG)\nRAG is an AI framework that retrieves relevant documents from a knowledge base and uses them to\naugment the context provided to a Large Language Model. This approach significantly improves factual\naccuracy and allows LLMs to access up-to-date information beyond their training cutoff.\nFigure 2: RAG Data Ingestion Pipeline Architecture\nRaw Data\nChunking\nEmbedding\nVector DB\n→\n→\n→\nRAG Data Ingestion Pipeline\nThe pipeline transforms raw documents into searchable vector embeddings stored in a vector database.\nRAG vs Fine-tuning Comparison\nCriteria\nRAG\nFine-tuning\nKnowledge Update\nReal-time, no retraining\nRequires full retraining\nCost\nLow (inference only)\nHigh (GPU training)\nAccuracy\nHigh with good retrieval\nHigh on specific domain\nHallucination\nReduced (grounded)\nStill possible\nLatency\nSlightly higher\nStandard inference\nBest Use Case\nDynamic knowledge bases\nFixed domain expertise\nKey Insight: RAG is preferred when the knowledge base changes frequently or when transparency and\nsource attribution are important. Fine-tuning is better for tasks requiring specific stylistic or behavioral\nchanges in the model.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-16T12:26:11+00:00', 'source': '..\\data\\pdf\\climate_change_report.pdf', 'file_path': '..\\data\\pdf\\climate_change_report.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-04-16T12:26:11+00:00', 'trapped': '', 'modDate': "D:20260416122611+00'00'", 'creationDate': "D:20260416122611+00'00'", 'page': 0}, page_content='Climate Change: Science, Data & Impact\nAnnual Scientific Assessment Report — 2024 Edition\nExecutive Summary\nGlobal average temperatures have risen by approximately 1.2°C above pre-industrial levels as of 2024.\nScientific consensus confirms that human activities—primarily the burning of fossil fuels, deforestation,\nand industrial processes—are the dominant cause of observed warming since the mid-20th century.\nWithout immediate and sustained reductions in greenhouse gas emissions, temperatures could rise by\n2.5°C to 4°C by the end of the century, with severe consequences for ecosystems, economies, and\nhuman populations.\n1. Temperature Trends\n1980\n1990\n2000\n2010\n2020\n14\n14.5\n15\n15.5\n16\nGlobal Average Temperature Rise (°C)\nFigure 1: Global mean surface temperature anomaly 1980–2024 (baseline: 1850–1900 average).\n1.1 Regional Temperature Anomalies (2024)\nRegion\nAnomaly (°C)\nTrend\nRisk Level\nArctic\n+3.8\nAccelerating\nCritical\nSub-Saharan Africa\n+1.9\nSteady rise\nHigh\nSouth Asia\n+1.6\nSteady rise\nHigh\nEurope\n+1.5\nModerate rise\nMedium-High\nNorth America\n+1.4\nModerate rise\nMedium\nSouth America\n+1.3\nSlow rise\nMedium\nGlobal Average\n+1.2\nAccelerating\nHigh\n2. Greenhouse Gas Emissions'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-16T12:26:11+00:00', 'source': '..\\data\\pdf\\climate_change_report.pdf', 'file_path': '..\\data\\pdf\\climate_change_report.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-04-16T12:26:11+00:00', 'trapped': '', 'modDate': "D:20260416122611+00'00'", 'creationDate': "D:20260416122611+00'00'", 'page': 1}, page_content='Fossil Fuels\nDeforestation\nAgriculture\nIndustryOther\nCO2 Emission Sources (%)\nFigure 2: Breakdown of global CO2-equivalent emissions by source sector.\n2.1 Top Emitting Countries (2023)\nCountry\nGtCO2e/yr\n% of Global\nPer Capita (tCO2e)\nChina\n14.4\n28.0%\n10.1\nUnited States\n6.0\n11.7%\n17.6\nIndia\n3.8\n7.4%\n2.7\nEuropean Union\n3.4\n6.6%\n7.6\nRussia\n2.3\n4.5%\n15.8\nJapan\n1.1\n2.1%\n8.8\nRest of World\n20.4\n39.7%\n—'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-16T12:26:11+00:00', 'source': '..\\data\\pdf\\climate_change_report.pdf', 'file_path': '..\\data\\pdf\\climate_change_report.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-04-16T12:26:11+00:00', 'trapped': '', 'modDate': "D:20260416122611+00'00'", 'creationDate': "D:20260416122611+00'00'", 'page': 2}, page_content="3. Impacts & Consequences\nImpact Category\nObserved (2024)\nProjected (2050)\nProjected (2100)\nSea Level Rise\n+20 cm since 1900\n+30–60 cm\n+60–110 cm\nArctic Ice Loss\n-40% since 1980\nSummer ice-free\nPermanent loss\nCoral Bleaching\n50% reefs affected\n70% reefs at risk\n90%+ reefs lost\nExtreme Heat Days\n+15 days/yr avg\n+30 days/yr\n+60 days/yr\nWildfire Area\n+2x since 1990\n+3–4x baseline\n+5x baseline\nSpecies at Risk\n~1M species\n~1.5M species\nMass extinction\nScientific Consensus: The IPCC Sixth Assessment Report (2023) concludes with 'unequivocal'\ncertainty that human influence has warmed the climate. Limiting warming to 1.5°C requires cutting\nglobal emissions by 45% by 2030 and reaching net-zero by 2050."),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-16T12:26:11+00:00', 'source': '..\\data\\pdf\\python_programming_reference.pdf', 'file_path': '..\\data\\pdf\\python_programming_reference.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-04-16T12:26:11+00:00', 'trapped': '', 'modDate': "D:20260416122611+00'00'", 'creationDate': "D:20260416122611+00'00'", 'page': 0}, page_content="Python Programming Reference Manual\nVersion 3.12 — Complete Developer Reference\n1. Core Data Structures\nListI[ ]\nOrdered\nDictI{ }\nKey-Value\nSetI{ }\nUnordered\nTupleI( )\nOrdered\nPython Core Data Structures\nFigure 1: Python's four primary built-in data structures and their key characteristics.\n1.1 Performance Comparison\nOperation\nList\nDict\nSet\nTuple\nLookup by index\nO(1)\nN/A\nN/A\nO(1)\nLookup by key/value\nO(n)\nO(1)\nO(1)\nO(n)\nInsert (end)\nO(1)*\nO(1)\nO(1)\nImmutable\nInsert (middle)\nO(n)\nN/A\nN/A\nImmutable\nDelete\nO(n)\nO(1)\nO(1)\nImmutable\nMemory usage\nLow\nMedium\nMedium\nLowest\nIteration\nO(n)\nO(n)\nO(n)\nO(n)\n1.2 Code Examples\n# List comprehension with filtering squares = [x**2 for x in range(10) if x % 2 == 0]\n# Dictionary comprehension word_len = {word: len(word) for word in ['python', 'rag',\n'llm']} # Set operations a, b = {1, 2, 3, 4}, {3, 4, 5, 6} union = a | b # {1, 2, 3,\n4, 5, 6} intersect = a & b # {3, 4}\n2. Python for AI/ML — Key Libraries\nLibrary\nVersion\nPrimary Use\nInstall Command\nNumPy\n1.26+\nNumerical computing, arrays\npip install numpy\nPandas\n2.1+\nData manipulation, DataFrames\npip install pandas\nScikit-learn\n1.4+\nClassical ML algorithms\npip install scikit-learn\nPyTorch\n2.2+\nDeep learning, neural nets\npip install torch"),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-16T12:26:11+00:00', 'source': '..\\data\\pdf\\python_programming_reference.pdf', 'file_path': '..\\data\\pdf\\python_programming_reference.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-04-16T12:26:11+00:00', 'trapped': '', 'modDate': "D:20260416122611+00'00'", 'creationDate': "D:20260416122611+00'00'", 'page': 1}, page_content='LangChain\n0.2+\nLLM application framework\npip install langchain\nLangGraph\n0.1+\nAgentic LLM workflows\npip install langgraph\nChromaDB\n0.4+\nVector database for RAG\npip install chromadb\nFAISS\n1.7+\nFast similarity search\npip install faiss-cpu\nPure Python\nNumPy\nCython\nC Extension\n0\n50\n100\nExecution Time vs Memory Usage by Approach\nFigure 2: Relative execution time and memory usage for different Python optimization approaches.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-04-16T12:26:11+00:00', 'source': '..\\data\\pdf\\python_programming_reference.pdf', 'file_path': '..\\data\\pdf\\python_programming_reference.pdf', 'total_pages': 3, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-04-16T12:26:11+00:00', 'trapped': '', 'modDate': "D:20260416122611+00'00'", 'creationDate': "D:20260416122611+00'00'", 'page': 2}, page_content="3. Building a RAG Pipeline in Python\nA RAG (Retrieval-Augmented Generation) pipeline in Python typically involves four main steps:\ndocument loading, text chunking, embedding generation, and vector storage. Here is a minimal but\ncomplete example using LangChain and ChromaDB:\nStep 1: Document Loading & Chunking\nfrom langchain.document_loaders import PyPDFLoader from langchain.text_splitter\nimport RecursiveCharacterTextSplitter loader = PyPDFLoader('document.pdf') documents\n= loader.load() splitter = RecursiveCharacterTextSplitter( chunk_size=1000,\nchunk_overlap=200 ) chunks = splitter.split_documents(documents)\nStep 2: Embedding & Vector Store\nfrom langchain_community.embeddings import HuggingFaceEmbeddings from\nlangchain_community.vectorstores import Chroma embeddings = HuggingFaceEmbeddings(\nmodel_name='sentence-transformers/all-MiniLM-L6-v2' ) vectordb =\nChroma.from_documents( documents=chunks, embedding=embeddings,\npersist_directory='./chroma_db' )\nStep 3: Query & Retrieve\nretriever = vectordb.as_retriever(search_kwargs={'k': 5}) # Retrieve relevant chunks\nquery = 'What is the RAG pipeline architecture?' relevant_docs =\nretriever.invoke(query) for i, doc in enumerate(relevant_docs): print(f'Chunk {i+1}:\n{doc.page_content[:200]}...')\nChunking Strategy Comparison\nStrategy\nChunk Size\nOverlap\nBest For\nFixed Size\n500–1000 tokens\n50–100 tokens\nGeneral purpose documents\nRecursive\n1000–1500 tokens\n100–200 tokens\nTechnical/structured docs\nSemantic\nVariable\nSentence boundary\nResearch papers, articles\nSliding Window\n512 tokens\n128 tokens\nDense information docs\nSentence-based\n3–5 sentences\n1 sentence\nConversational content\nPro Tip: For your LangGraph + Groq RAG project, use RecursiveCharacterTextSplitter with\nchunk_size=1000 and chunk_overlap=150. Pair it with ChromaDB for local vector storage and\nall-MiniLM-L6-v2 for fast, lightweight embeddings.")]
